# %%
#importing necessary tools
import pandas as pd
#reading provided CSV data
df=pd.read_csv('train_revised.csv')
#converting travel date to datetime
df['date'] = pd.to_datetime(df['travel_date'],format= "%d-%m-%y").dt.weekday
#extracting Sunday data only
modified_df=df.loc[df["date"]==6]
print(modified_df)
#Counting the routes
Awendo=modified_df.loc[modified_df['travel_from']=='Awendo'].count()
Homabay=modified_df.loc[modified_df['travel_from']=='Homabay'].count()
Kehancha=modified_df.loc[modified_df['travel_from']=='Kehancha'].count()
Kendu_Bay=modified_df.loc[modified_df['travel_from']=='Kendu Bay'].count()
Keroka=modified_df.loc[modified_df['travel_from']=='Keroka'].count()
Keumbu=modified_df.loc[modified_df['travel_from']=='Keumbu'].count()
Kijauri=modified_df.loc[modified_df['travel_from']=='Kijauri'].count()
Kisii=modified_df.loc[modified_df['travel_from']=='Kisii'].count()
Mbita=modified_df.loc[modified_df['travel_from']=='Mbita'].count()
Migori=modified_df.loc[modified_df['travel_from']=='Migori'].count()
Ndhiwa=modified_df.loc[modified_df['travel_from']=='Ndhiwa'].count()
Nyachenge=modified_df.loc[modified_df['travel_from']=='Nyachenge'].count()
Oyugis=modified_df.loc[modified_df['travel_from']=='Oyugis'].count()
Rodi=modified_df.loc[modified_df['travel_from']=='Rodi'].count()
Rong=modified_df.loc[modified_df['travel_from']=='Rong'].count()
Sirare=modified_df.loc[modified_df['travel_from']=='Sirare'].count()
Sori=modified_df.loc[modified_df['travel_from']=='Sori'].count()
print(Awendo,Homabay,Kehancha,Kendu_Bay,Keroka,Keumbu,Kijauri,Kisii,Mbita,Migori,Ndhiwa,Nyachenge,Oyugis,Rodi,Rong,Sirare,Sori)
#from values  obtained#ranking from most travelled from to least
Kisii_value='3607'
Migori_value='954'
Sirare_value='634'
Kehancha_value="294"
Awendo_value="270"
Keroka_value='145'
Kijauri_value='138'
Nyachenge_value='107'
Mbita_value='73'
Rodi_value='50'
Ndhiwa_value='22'
Keumbu_value='3'
Homabay_value="0"
Sori_value='3'
Kendu_bay_value='0'
Oyugis_value='0'
Rong_value='0'
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 1         5437         14A          Mpesa      TIHLBUSGTE    19-11-17
# 2         5710          8B          Mpesa      EQX8Q5G19O    26-11-17
# 111       5856           9           Cash      MDF1ULUMPX    15-04-18
# 112       5857           6           Cash      MDF1ULG1GR    15-04-18
# 113       5857           3           Cash      MDF6ULD8NQ    15-04-18
# ...        ...         ...            ...             ...         ...
# 49784    13534          8A          Mpesa      DDLUTQQJ2C    15-04-18
# 49785    13534          7A          Mpesa      GVJSWN57XJ    15-04-18
# 49786    13535         15A          Mpesa      MI27JEXM0L    15-04-18
# 49787    13541          2B          Mpesa      ICOT1CSM7F    15-04-18
# 49788    13547         15A          Mpesa      X9XZAPYDCG    15-04-18
#
#       travel_time travel_from travel_to car_type  max_capacity  date
# ...

# %%
#importing necessary tools
import pandas as pd
import tensorflow as tensorflow
from tensorflow.keras import layers
import numpy as np
#reading provided CSV data
df=pd.read_csv('train_revised.csv')
print(df)
df_new = np.where(df['payment_receipt']=='MK')
print (df_new)
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO    17-10-17
# 1         5437         14A          Mpesa      TIHLBUSGTE    19-11-17
# 2         5710          8B          Mpesa      EQX8Q5G19O    26-11-17
# 3         5777         19A          Mpesa      SGP18CL0ME    27-11-17
# 4         5778         11A          Mpesa      BM97HFRGL9    27-11-17
# ...        ...         ...            ...             ...         ...
# 51640    13826          9B          Mpesa      8V2XDDZR6V    20-04-18
# 51641    13809         18A          Mpesa      4PEBSVJSNK    20-04-18
# 51642    13809         17A          Mpesa      LVN64LZDNN    20-04-18
# 51643    13796         16B          Mpesa      REYBSKTYWN    20-04-18
# 51644    14304           7          Mpesa      AQN7FBUSGP    14-11-17
#
#       travel_time travel_from travel_to car_type  max_capacity
# 0            7:15      Migori   Nairobi      Bus            49
# ...
